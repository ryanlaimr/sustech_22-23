# %% [markdown]
# # Assignment Part 1: Economy Data Visualization
#
# In this assignment, you will be working with city-wide economic data for China from 2010 to 2019. This data includes information on population size, urbanization rate, and disposable income for various cities in China. You will use the Python libraries Numpy, Pandas, and Matplotlib to analyze and visualize this data, and gain insights into trends and patterns in the Chinese economy over the past decade. You will start by reading the data into a Pandas dataframe, and then use Numpy and Pandas to manipulate and summarize the data. You will then use Matplotlib to create plots and charts to visualize the data and uncover trends and patterns.
#
# By completing this assignment, you will gain hands-on experience with these important tools for data analysis and visualization in Python, and develop your skills in working with real-world data.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

census = pd.read_csv('census.csv')
census = census.fillna(0)

# %% [markdown]
# # Task 1: Urbanization Analysis

# %%
"""
Preprocess dataframe.
"""
dataframe = pd.DataFrame(census, columns=['year', 'dum', 'urbanization_rate', 'urban_disposable_income', 'rural_disposable_income'])
dataframe
# Out:
#       year        dum  urbanization_rate  urban_disposable_income  \
# 0     2010    Beijing              0.860                  29072.9
# 1     2011    Beijing              0.862                  32903.0
# 2     2012    Beijing              0.862                  36468.8
# 3     2013    Beijing              0.863                  40321.0
# 4     2014    Beijing              0.864                  48531.8
# ...    ...        ...                ...                      ...
# 2045  2015  Chongqing              0.609                  27238.8
# 2046  2016  Chongqing              0.626                  29610.0
# 2047  2017  Chongqing              0.641                  32193.2
# 2048  2018  Chongqing              0.655                  34889.3
# 2049  2019  Chongqing              0.668                  37938.6
#
#       rural_disposable_income
# 0                     13262.3
# 1                     14735.7
# 2                     16475.7
# 3                     18337.5
# 4                     18867.3
# ...                       ...
# 2045                  10504.7
# 2046                  11548.8
# 2047                  12637.9
# 2048                  13781.2
# 2049                  15133.3
#
# [2050 rows x 5 columns]

# %% [markdown]
# We have the urbanization_rate of several cities between 2010 and 2019.
# Now, we are going to find the most `successful` city on urbanization.
# For example, Beijing's urbanization_rate is 0.860 on 2010 and 0.866 on 2019.
# Beijing has a 0.006 improvement.
# The task is to find the city with the highest improvement.
#
# We visualize the average urbanization_rate from 2010 to 2019.
# It is promising to find that the urbanization_rate improves gradually recent years.

# %%
plt.figure(figsize=(10,10))

# TODO: use seaborn.lineplot to plot the grneral urbanization rate
############# YOUR CODE HERE #############
############# YOUR CODE HERE #############
sns.lineplot(data=dataframe, x='dum', y='urbanization_rate')
plt.show()

# %% [markdown]
# Now, we need to collect the improvements for all the cities.
# Specifically, `collected_urban_rates` is a numpy array with shape [num_cities, 2].
# Each row contains urbanization rates of a city on 2010 and 2019, respectively.

# %%
cities = list(set(dataframe['dum']))
# print(cities)

# TODO: Obtain `collected_urban_rates`
############# YOUR CODE HERE #############
urban_rates_list = []
for city in cities:
    cityframe = dataframe.loc[dataframe['dum'] == city]
    rate2010 = cityframe['urbanization_rate'].tolist()[0]
    rate2019 = cityframe['urbanization_rate'].tolist()[-1]
    urban_rates_list.append([rate2010, rate2019])
collected_urban_rates = np.array(urban_rates_list)
print(collected_urban_rates)
idx = np.argmax(collected_urban_rates[:, 1] - collected_urban_rates[:, 0])
print(f"The most successful city is {cities[idx]}, the urbanization rate improves from {collected_urban_rates[idx, 0]} to {collected_urban_rates[idx, 1]}.")
# ############# YOUR CODE HERE #############
# Out:
# [[0.592 0.7  ]
#  [0.396 0.501]
#  [0.276 0.433]
#  [0.529 0.645]
#  [0.472 0.608]
#  [0.885 0.921]
#  [0.532 0.667]
#  [0.319 0.446]
#  [0.551 0.654]
#  [0.632 0.712]
#  [0.43  0.53 ]
#  [0.197 0.348]
#  [0.399 0.541]
#  [0.357 0.471]
#  [0.7   0.44 ]
#  [0.298 0.4  ]
#  [0.401 0.527]
#  [0.542 0.552]
#  [0.558 0.681]
#  [0.478 0.613]
#  [0.355 0.496]
#  [0.468 0.536]
#  [0.658 0.744]
#  [0.796 0.835]
#  [0.402 0.51 ]
#  [0.52  0.649]
#  [0.636 0.686]
#  [0.479 0.576]
#  [0.627 0.658]
#  [0.395 0.534]
#  [0.616 0.701]
#  [0.298 0.443]
#  [0.548 0.65 ]
#  [0.291 0.422]
#  [0.623 0.667]
#  [0.86  0.866]
#  [0.637 0.728]
#  [0.376 0.525]
#  [0.508 0.617]
#  [0.328 0.528]
#  [0.683 0.736]
#  [0.375 0.518]
#  [1.    0.995]
#  [0.425 0.568]
#  [0.876 0.907]
#  [0.355 0.512]
#  [0.463 0.565]
#  [0.63  0.763]
#  [0.62  0.513]
#  [0.353 0.469]
#  [0.238 0.399]
#  [0.298 0.449]
#  [0.332 0.457]
#  [0.362 0.505]
#  [0.501 0.638]
#  [0.411 0.525]
#  [0.379 0.528]
#  [0.59  0.687]
#  [0.399 0.529]
#  [0.345 0.62 ]
#  [0.703 0.771]
#  [0.293 0.434]
#  [0.4   0.465]
#  [0.779 0.832]
#  [0.359 0.497]
#  [0.441 0.6  ]
#  [0.387 0.532]
#  [0.473 0.512]
#  [0.328 0.488]
#  [0.467 0.6  ]
#  [0.5   0.624]
#  [0.33  0.478]
#  [0.413 0.539]
#  [0.58  0.691]
#  [0.378 0.53 ]
#  [0.35  0.493]
#  [0.45  0.586]
#  [0.41  0.541]
#  [0.205 0.353]
#  [0.388 0.509]
#  [0.475 0.535]
#  [0.321 0.582]
#  [0.384 0.515]
#  [0.361 0.5  ]
#  [0.496 0.622]
#  [0.6   0.695]
#  [0.621 0.71 ]
#  [0.395 0.514]
#  [0.33  0.472]
#  [0.448 0.   ]
#  [0.463 0.575]
#  [0.444 0.575]
#  [0.388 0.52 ]
#  [0.327 0.471]
#  [0.463 0.687]
#  [0.266 0.375]
#  [0.433 0.563]
#  [0.297 0.445]
#  [0.586 0.684]
#  [0.579 0.663]
#  [0.402 0.72 ]
#  [0.62  0.722]
#  [0.291 0.42 ]
#  [0.362 0.61 ]
#  [0.568 0.682]
#  [0.416 0.545]
#  [0.507 0.575]
#  [0.647 0.737]
#  [0.466 0.572]
#  [0.417 0.56 ]
#  [0.379 0.517]
#  [0.397 0.692]
#  [0.413 0.555]
#  [0.45  0.58 ]
#  [0.685 0.704]
#  [0.273 0.388]
#  [0.508 0.635]
#  [0.632 0.733]
#  [0.556 0.637]
#  [0.367 0.44 ]
#  [0.408 0.536]
#  [0.499 0.618]
#  [0.37  0.48 ]
#  [0.291 0.433]
#  [0.234 0.364]
#  [0.584 0.672]
#  [0.55  0.741]
#  [0.636 0.746]
#  [0.444 0.591]
#  [0.354 0.509]
#  [0.361 0.49 ]
#  [0.568 0.64 ]
#  [0.486 0.594]
#  [0.53  0.668]
#  [0.348 0.486]
#  [0.445 0.549]
#  [0.601 0.668]
#  [0.273 0.416]
#  [0.307 0.41 ]
#  [0.838 0.865]
#  [0.346 0.484]
#  [0.418 0.549]
#  [0.392 0.543]
#  [0.419 0.535]
#  [0.636 0.736]
#  [0.359 0.503]
#  [0.43  0.515]
#  [0.341 0.478]
#  [0.445 0.549]
#  [0.933 0.937]
#  [0.46  0.583]
#  [0.455 0.601]
#  [0.657 0.752]
#  [0.228 0.41 ]
#  [0.763 0.81 ]
#  [0.32  0.527]
#  [0.284 0.423]
#  [0.424 0.486]
#  [0.38  0.512]
#  [0.329 0.597]
#  [0.37  0.429]
#  [0.677 0.796]
#  [0.394 0.506]
#  [0.484 0.63 ]
#  [0.511 0.609]
#  [0.825 0.852]
#  [0.412 0.549]
#  [0.483 0.611]
#  [0.303 0.446]
#  [0.563 0.68 ]
#  [0.526 0.637]
#  [0.545 0.659]
#  [0.483 0.597]
#  [0.618 0.721]
#  [0.51  0.617]
#  [0.223 0.385]
#  [0.883 0.892]
#  [0.464 0.654]
#  [0.878 0.884]
#  [0.474 0.62 ]
#  [0.66  0.705]
#  [0.555 0.679]
#  [0.376 0.512]
#  [0.351 0.448]
#  [0.893 0.883]
#  [0.533 0.674]
#  [0.941 0.95 ]
#  [0.525 0.574]
#  [0.314 0.468]
#  [0.291 0.431]
#  [0.344 0.491]
#  [0.546 0.664]
#  [0.549 0.656]
#  [0.436 0.564]
#  [0.43  0.544]
#  [0.51  0.608]
#  [0.441 0.568]
#  [0.733 0.785]
#  [0.46  0.592]
#  [0.518 0.636]
#  [0.302 0.53 ]
#  [0.327 0.442]]
# The most successful city is Zibo City, the urbanization rate improves from 0.402 to 0.72.

# %% [markdown]
# # Task 2: Economy Data Visualization
#
# In this task, we are going to visualize some economy data and trends in the dataset.

# %%
# TODO: plot the line plot of urban disposable income of `Beijing`, `Guangzhou City`, `Shanghai` and `Shenzhen`

############## YOUR CODE HERE ##############
econ = pd.DataFrame(census, columns=['year', 'dum', 'urban_disposable_income'])
#create the sub-dataframe of each city
BeijingEcon = econ.loc[econ['dum'] == 'Beijing']
ShanghaiEcon = econ.loc[econ['dum'] == 'Shanghai']
GuangzhouEcon = econ.loc[econ['dum'] == 'Guangzhou City']
ShenzhenEcon = econ.loc[econ['dum'] == 'Shenzhen']
#convert the data to list for future plotting & analysis
yearList = BeijingEcon['year'].tolist()
Beijing_econ_list = BeijingEcon['urban_disposable_income'].tolist()
Shanghai_econ_list = ShanghaiEcon['urban_disposable_income'].tolist()
Guangzhou_econ_list = GuangzhouEcon['urban_disposable_income'].tolist()
Shenzhen_econ_list = ShenzhenEcon['urban_disposable_income'].tolist()
#plot the figure
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(yearList, Beijing_econ_list, 'ro-.')
ax.plot(yearList, Shanghai_econ_list, 'gx--')
ax.plot(yearList, Guangzhou_econ_list, 'mx:')
ax.plot(yearList, Shenzhen_econ_list, 'cD-')
ax.set_title('econ data')
ax.set_xlabel('year')
ax.set_ylabel('urban disposable income')
plt.show()
############# YOUR CODE HERE #############

# %% [markdown]
# The Theil index is a statistic primarily used to measure economic inequality. For more information, you can refer to https://en.wikipedia.org/wiki/Theil_index
# Here, let's find out the cities who has higher Theil index in 2019 than that in 2010, and then draw a bar plot of their change from 2010 to 2019.

# %%
# TODO: find out the cities who has higher Theil index in 2019 than that in 2010, and then draw a bar plot of their change from 2010 to 2019.

############## YOUR CODE HERE ##############
TheilIndex = pd.DataFrame(census, columns=['year', 'dum', 'theil_index'])
theilList = []
for city in cities:
    cityframe = TheilIndex[TheilIndex['dum'] == city]
    citytheil = cityframe['theil_index'].tolist()
    if citytheil[-1] > citytheil[0]:
        theilList.append(city)
    # plot the bar of each city according to the instruction:

    # fig = plt.figure()
    # ax = fig.add_axes([0,0,1,1])
    # ax.bar(yearList, citytheil)
    # plt.show()

print('The cities with higher Theil index in 2019 than 2010 are:')
for city in theilList:
    print(city)
############## YOUR CODE HERE ##############
# Out:
# The cities with higher Theil index in 2019 than 2010 are:
# Suzhou City
# Beijing
# Linyi City
# Shenzhen
# Shanghai

# %% [markdown]
# # Task 3: Disposable income
#
# In this task, you need to analyze average disposable income in the dataset.

# %% [markdown]
# First, you need to calculate the disposable income for each city. Suppose this can be calculated by:
# $$ \text{disposable\_income} =\text{urban\_disposable\_income}\times \text{urbanization\_rate}+\text{rural\_disposable\_income}\times(1-\text{urbanization\_rate})$$

# %%
## TODO Calculate disposable_income
data = pd.DataFrame(census, columns=['year', 'dum', 'urban_disposable_income', 'urbanization_rate', 'rural_disposable_income', 'total_income'])
data['disposable_income'] = data['urban_disposable_income'] * data['urbanization_rate'] + data['rural_disposable_income'] * (1 - data['urbanization_rate'])
print(data)
# Out:
#       year        dum  urban_disposable_income  urbanization_rate  \
# 0     2010    Beijing                  29072.9              0.860
# 1     2011    Beijing                  32903.0              0.862
# 2     2012    Beijing                  36468.8              0.862
# 3     2013    Beijing                  40321.0              0.863
# 4     2014    Beijing                  48531.8              0.864
# ...    ...        ...                      ...                ...
# 2045  2015  Chongqing                  27238.8              0.609
# 2046  2016  Chongqing                  29610.0              0.626
# 2047  2017  Chongqing                  32193.2              0.641
# 2048  2018  Chongqing                  34889.3              0.655
# 2049  2019  Chongqing                  37938.6              0.668
#
#       rural_disposable_income  total_income  disposable_income
# 0                     13262.3   52683080.72         26859.4160
# 1                     14735.7   61357189.17         30395.9126
# 2                     16475.7   69755590.23         33709.7522
# 3                     18337.5   78901624.11         37309.2605
# 4                     18867.3   95708753.02         44497.4280
# ...                       ...           ...                ...
# 2045                  10504.7   62450007.34         20695.7669
# 2046                  11548.8   69662378.94         22855.1112
# 2047                  12637.9   77398505.97         25172.8473
# 2048                  13781.2   85636931.06         27607.0055
# 2049                  15133.3   94876976.53         30367.2404
#
# [2050 rows x 7 columns]

# %% [markdown]
# Then, calculate the average disposable income and total income for each city from 2011 to 2019.

# %%
## TODO Calculate average disposable_income and total_income from 2011 to 2019
############## YOUR CODE HERE ##############
avg_disposable_income = {}
for city in cities:
    dfPerCity = data.loc[data['dum'] == city]
    avgIncome = sum(dfPerCity['disposable_income'].tolist()) / 9
    avg_disposable_income.update({city: avgIncome})
for city in cities:
    print(f'The average disposable income of {city} is {round(avg_disposable_income[city])}')

############## YOUR CODE HERE ##############
# Out:
# The average disposable income of Pingxiang is 24960
# The average disposable income of Yulin City is 20194
# The average disposable income of Wuwei City is 14291
# The average disposable income of Huzhou is 37902
# The average disposable income of Jiaozuo City is 21675
# The average disposable income of Dongguan city is 46558
# The average disposable income of Xuzhou is 23623
# The average disposable income of Fuyang City is 15790
# The average disposable income of Liuzhou is 22791
# The average disposable income of Jinan City is 34739
# The average disposable income of Wuzhou is 18678
# The average disposable income of Longnan City is 9553
# The average disposable income of Mianyang City is 20650
# The average disposable income of Lu'an City is 16369
# The average disposable income of Suzhou City is 63610
# The average disposable income of Chongzuo is 15716
# The average disposable income of Suizhou is 19042
# The average disposable income of Shanwei City is 18276
# The average disposable income of Nantong city is 31764
# The average disposable income of Hebi is 20876
# The average disposable income of Qujing City is 18367
# The average disposable income of Yangjiang is 19592
# The average disposable income of Chengdu is 30998
# The average disposable income of Tianjin is 35046
# The average disposable income of Guigang is 18409
# The average disposable income of Yancheng City is 25125
# The average disposable income of Zhoushan City is 41444
# The average disposable income of Ningde is 21568
# The average disposable income of Chaozhou is 18750
# The average disposable income of Leshan is 19906
# The average disposable income of Xinyu City is 26387
# The average disposable income of Zhoukou City is 14281
# The average disposable income of Huainan City is 21833
# The average disposable income of Bozhou is 16078
# The average disposable income of Jiangmen is 26296
# The average disposable income of Beijing is 51255
# The average disposable income of Xining is 21769
# The average disposable income of Ji'an City is 19400
# The average disposable income of Putian City is 24883
# The average disposable income of Linyi City is 22620
# The average disposable income of Ningbo is 44989
# The average disposable income of Ganzhou City is 16869
# The average disposable income of Shenzhen is 51219
# The average disposable income of Jiujiang City is 20789
# The average disposable income of Zhuhai city is 41083
# The average disposable income of Yichun City is 18899
# The average disposable income of Shiyan City is 17428
# The average disposable income of Hefei is 29456
# The average disposable income of Fuzhou is 50291
# The average disposable income of Hezhou is 16783
# The average disposable income of Qingyang City is 12864
# The average disposable income of Shangqiu is 15650
# The average disposable income of Laibin City is 17460
